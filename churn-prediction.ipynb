# %%
# Core Libraries
import numpy as np
import pandas as pd
import time
import warnings
import re

# Data Splitting and Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from imblearn.under_sampling import RandomUnderSampler

# Models
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV

# Metrics for Model Evaluation
from sklearn.metrics import classification_report

# Utilities
from rapidfuzz import process, fuzz
from sklearn.base import BaseEstimator, TransformerMixin

# Filter Warnings
warnings.filterwarnings("ignore")

# %%
train=pd.read_csv('../data/train.csv')
test=pd.read_csv('../data/test.csv', dtype={'start_dt': 'object'})

# %%
pd.set_option('display.max_columns', None) #отображение всех столбцов

# %%
train.head()
# Out:
#    monthly_income  work_experience  requested_sum  main_agreement_amount  \
# 0       -0.000735         0.952894            NaN              -0.388291
# 1       -0.000742         0.952894            NaN              -0.388291
# 2       -0.000742         0.952894            NaN              -0.388291
# 3       -0.000742         0.952894            NaN              -0.388291
# 4       -0.000742         0.952894            NaN              -0.388291
#
#    main_agreement_term  requested_period_days  requested_amount  \
# 0            -0.340659              -0.389028         -1.053530
# 1            -1.145865              -1.294731         -0.436189
# 2            -0.685747              -1.113590         -0.259806
# 3             0.176974              -1.385301          1.239449
# 4            -1.145865              -1.657011          0.357534
#
#    req_app_amount  approved_amount  period_days  days_finish_loan        ag  \
# 0       -0.629296         -0.61762    -0.340659         -0.539615 -0.619312
# 1       -0.020140         -0.61762    -1.145865         -0.539615  1.354330
# 2        0.153905         -0.61762    -0.685747         -0.502706  1.354330
# 3        1.633284         -0.61762     0.176974         -0.465796  1.354330
# 4        0.763061         -0.61762    -1.145865         -0.133607  1.354330
#
#     cnt_ext      term     price  elecs_sum  recurents_sum   tamount    issues  \
# 0       NaN       NaN       NaN  -0.063933      -0.143015 -0.434972  0.347703
# 1       NaN       NaN       NaN  -0.063933      -0.143015 -0.434972  0.347703
# 2       NaN       NaN       NaN  -0.063933      -0.143015 -0.429509  0.347703
# 3       NaN       NaN       NaN  -0.063933      -0.143015 -0.413118  0.347703
# 4  1.407752 -0.612324 -0.705103  -0.063933      -0.143015 -0.320236  0.347703
#
#    principal  interest  overdue_interest  overdue_fee  nbki_score  \
# 0  -0.347703 -0.502878         -0.218265    -0.185707    1.837622
# 1  -0.347703 -0.502878         -0.218265    -0.185707    2.262600
# 2  -0.347703 -0.484111         -0.218265    -0.185707    2.262600
# 3  -0.347703 -0.427809         -0.218265    -0.185707    2.262600
# 4  -0.347703 -0.108766         -0.218265    -0.185707    2.262600
#
#    payment_frequency  status  loan_id  client_id  source  first_source  \
# 0                  2       1   464867     111035      11             0
# 1                  2       1  4569010     604426      11             0
# 2                  2       1   985489     334703      11             4
# 3                  2       6  2247534     362893      11             0
# 4                  2       1  4695006     537669      11            11
#
#    interface  type  repayment_type  client_type settlement client_type.1  \
# 0          0     2               3            1   г Москва      repeated
# 1          2     1               0            1   г Москва      repeated
# 2          2     2               3            1    г Пермь      repeated
# 3          2     2               1            1   г Самара      repeated
# 4          2     1               2            1   г Москва      repeated
#
#           region  gender  loan_order  have_extension  contact_cases  \
# 0       г Москва    male           2               0            NaN
# 1       г Москва  female          14               0            NaN
# 2  край Пермский    male          10               0            NaN
# 3  обл Самарская  female           2               1            NaN
# 4       г Москва  female          17               0            NaN
#
#             created_at            closed_at             start_dt  churn
# 0  2022-12-23 17:50:25  2022-12-31 16:09:23                  NaN      0
# 1  2024-06-29 22:26:08  2024-07-27 16:21:49                  NaN      0
# 2  2023-04-10 21:06:38  2023-05-10 07:51:18                  NaN      0
# 3  2023-10-01 00:13:16  2024-01-12 17:40:14  2024-01-12 17:29:21      0
# 4  2024-07-15 10:40:35  2024-07-18 12:20:08                  NaN      0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4036207 entries, 0 to 4036206
# Data columns (total 45 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   monthly_income         float64
#  1   work_experience        float64
#  2   requested_sum          float64
#  3   main_agreement_amount  float64
#  4   main_agreement_term    float64
#  5   requested_period_days  float64
#  6   requested_amount       float64
#  7   req_app_amount         float64
#  8   approved_amount        float64
#  9   period_days            float64
#  10  days_finish_loan       float64
#  11  ag                     float64
#  12  cnt_ext                float64
#  13  term                   float64
#  14  price                  float64
#  15  elecs_sum              float64
#  16  recurents_sum          float64
#  17  tamount                float64
#  18  issues                 float64
#  19  principal              float64
#  20  interest               float64
#  21  overdue_interest       float64
#  22  overdue_fee            float64
#  23  nbki_score             float64
#  24  payment_frequency      int64
#  25  status                 int64
#  26  loan_id                int64
#  27  client_id              int64
#  28  source                 int64
#  29  first_source           int64
#  30  interface              int64
#  31  type                   int64
#  32  repayment_type         int64
#  33  client_type            int64
#  34  settlement             object
#  35  client_type.1          object
#  36  region                 object
#  37  gender                 object
#  38  loan_order             int64
#  39  have_extension         int64
#  40  contact_cases          float64
#  41  created_at             object
#  42  closed_at              object
#  43  start_dt               object
#  44  churn                  int64
# dtypes: float64(25), int64(13), object(7)
# memory usage: 1.4+ GB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348743 entries, 0 to 1348742
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   monthly_income         1348680 non-null  float64
#  1   work_experience        463225 non-null   float64
#  2   requested_sum          163790 non-null   float64
#  3   main_agreement_amount  1348743 non-null  float64
#  4   main_agreement_term    1348743 non-null  float64
#  5   requested_period_days  1200882 non-null  float64
#  6   requested_amount       1209772 non-null  float64
#  7   req_app_amount         1209772 non-null  float64
#  8   approved_amount        1348743 non-null  float64
#  9   period_days            1348743 non-null  float64
#  10  days_finish_loan       1348743 non-null  float64
#  11  ag                     1348743 non-null  float64
#  12  cnt_ext                151701 non-null   float64
#  13  term                   151701 non-null   float64
#  14  price                  151610 non-null   float64
#  15  elecs_sum              1346759 non-null  float64
#  16  recurents_sum          1346759 non-null  float64
#  17  tamount                1348125 non-null  float64
#  18  issues                 1348743 non-null  float64
#  19  principal              1348743 non-null  float64
#  20  interest               1348743 non-null  float64
#  21  overdue_interest       1348743 non-null  float64
#  22  overdue_fee            1348743 non-null  float64
#  23  nbki_score             1320766 non-null  float64
#  24  payment_frequency      1348743 non-null  int64
#  25  status                 1348743 non-null  int64
#  26  loan_id                1348743 non-null  int64
#  27  client_id              1348743 non-null  int64
#  28  source                 1348743 non-null  int64
#  29  first_source           1348743 non-null  int64
#  30  interface              1348743 non-null  int64
#  31  type                   1348743 non-null  int64
#  32  repayment_type         1348743 non-null  int64
#  33  client_type            1348743 non-null  int64
#  34  settlement             1348743 non-null  object
#  35  client_type.1          1348743 non-null  object
#  36  region                 1348743 non-null  object
#  37  gender                 1348743 non-null  object
#  38  loan_order             1348743 non-null  int64
#  39  have_extension         1348743 non-null  int64
#  40  contact_cases          75952 non-null    float64
#  41  created_at             1348743 non-null  object
#  42  start_dt               151075 non-null   object
# dtypes: float64(25), int64(12), object(6)
# memory usage: 442.5+ MB

# %%
optimized_types = {
    "monthly_income": np.float32,
    "work_experience": np.float32,
    "requested_sum": np.float32,
    "main_agreement_amount": np.float32,
    "main_agreement_term": np.float32,
    "requested_period_days": np.float32,
    "requested_amount": np.float32,
    "req_app_amount": np.float32,
    "approved_amount": np.float32,
    "period_days": np.float32,
    "days_finish_loan": np.float32,
    "ag": np.float32,
    "cnt_ext": np.float32,
    "term": np.float32,
    "price": np.float32,
    "elecs_sum": np.float32,
    "recurents_sum": np.float32,
    "tamount": np.float32,
    "issues": np.float32,
    "principal": np.float32,
    "interest": np.float32,
    "overdue_interest": np.float32,
    "overdue_fee": np.float32,
    "nbki_score": np.float32,
    "contact_cases": np.float32,
    "payment_frequency": np.int32,
    "status": np.int32,
    "loan_id": np.int32,
    "client_id": np.int32,
    "source": np.int32,
    "first_source": np.int32,
    "interface": np.int32,
    "type": np.int32,
    "repayment_type": np.int32,
    "client_type": np.int32,
    "loan_order": np.int32,
    "have_extension": np.int32,
    "churn": np.int32,
    "settlement": "category",
    "client_type.1": "category",
    "region": "category",
    "gender": "category",
    "created_at": "datetime64[ns]",
    "closed_at": "datetime64[ns]",
    "start_dt": "datetime64[ns]"
}
train = train.astype(optimized_types)

optimized_types_test = {col: dtype for col, dtype in optimized_types.items() if col in test.columns}
test = test.astype(optimized_types_test)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4036207 entries, 0 to 4036206
# Data columns (total 45 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   monthly_income         float32
#  1   work_experience        float32
#  2   requested_sum          float32
#  3   main_agreement_amount  float32
#  4   main_agreement_term    float32
#  5   requested_period_days  float32
#  6   requested_amount       float32
#  7   req_app_amount         float32
#  8   approved_amount        float32
#  9   period_days            float32
#  10  days_finish_loan       float32
#  11  ag                     float32
#  12  cnt_ext                float32
#  13  term                   float32
#  14  price                  float32
#  15  elecs_sum              float32
#  16  recurents_sum          float32
#  17  tamount                float32
#  18  issues                 float32
#  19  principal              float32
#  20  interest               float32
#  21  overdue_interest       float32
#  22  overdue_fee            float32
#  23  nbki_score             float32
#  24  payment_frequency      int32
#  25  status                 int32
#  26  loan_id                int32
#  27  client_id              int32
#  28  source                 int32
#  29  first_source           int32
#  30  interface              int32
#  31  type                   int32
#  32  repayment_type         int32
#  33  client_type            int32
#  34  settlement             category
#  35  client_type.1          category
#  36  region                 category
#  37  gender                 category
#  38  loan_order             int32
#  39  have_extension         int32
#  40  contact_cases          float32
#  41  created_at             datetime64[ns]
#  42  closed_at              datetime64[ns]
#  43  start_dt               datetime64[ns]
#  44  churn                  int32
# dtypes: category(4), datetime64[ns](3), float32(25), int32(13)
# memory usage: 709.6 MB

# %%
train.isnull().sum()
# Out:
# monthly_income               207
# work_experience          2648360
# requested_sum            3546390
# main_agreement_amount          0
# main_agreement_term            0
# requested_period_days     441618
# requested_amount          414836
# req_app_amount            414836
# approved_amount                0
# period_days                    0
# days_finish_loan               0
# ag                             0
# cnt_ext                  3582556
# term                     3582556
# price                    3582816
# elecs_sum                   5794
# recurents_sum               5794
# tamount                     1774
# issues                         0
# principal                      0
# interest                       0
# overdue_interest               0
# overdue_fee                    0
# nbki_score                 84476
# payment_frequency              0
# status                         0
# loan_id                        0
# client_id                      0
# source                         0
# first_source                   0
# interface                      0
# type                           0
# repayment_type                 0
# client_type                    0
# settlement                     0
# client_type.1                  0
# region                         0
# gender                         0
# loan_order                     0
# have_extension                 0
# contact_cases            3810290
# created_at                     0
# closed_at                      0
# start_dt                 3581930
# churn                          0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# monthly_income                63
# work_experience           885518
# requested_sum            1184953
# main_agreement_amount          0
# main_agreement_term            0
# requested_period_days     147861
# requested_amount          138971
# req_app_amount            138971
# approved_amount                0
# period_days                    0
# days_finish_loan               0
# ag                             0
# cnt_ext                  1197042
# term                     1197042
# price                    1197133
# elecs_sum                   1984
# recurents_sum               1984
# tamount                      618
# issues                         0
# principal                      0
# interest                       0
# overdue_interest               0
# overdue_fee                    0
# nbki_score                 27977
# payment_frequency              0
# status                         0
# loan_id                        0
# client_id                      0
# source                         0
# first_source                   0
# interface                      0
# type                           0
# repayment_type                 0
# client_type                    0
# settlement                     0
# client_type.1                  0
# region                         0
# gender                         0
# loan_order                     0
# have_extension                 0
# contact_cases            1272791
# created_at                     0
# start_dt                 1197668
# dtype: int64

# %%
train['region'].head(50)
# Out:
# 0                                        г Москва
# 1                                        г Москва
# 2                                   край Пермский
# 3                                   обл Самарская
# 4                                        г Москва
# 5                                 Респ Удмуртская
# 6                             обл Калининградская
# 7                               обл Ленинградская
# 8                                 обл Челябинская
# 9                                  обл Московская
# 10                            край Ставропольский
# 11    АО Ханты-Мансийский Автономный округ - Югра
# 12                              Респ Башкортостан
# 13                                обл Ульяновская
# 14                                обл Челябинская
# 15                              край Красноярский
# 16                              г Санкт-Петербург
# 17                                 Респ Татарстан
# 18    АО Ханты-Мансийский Автономный округ - Югра
# 19                              обл Новосибирская
# 20                                 обл Ивановская
# 21                                г Москва Москва
# 22                                     обл Омская
# 23                                обл Челябинская
# 24                                   Респ Бурятия
# 25                              обл Ленинградская
# 26                                   обл Брянская
# 27                                       г Москва
# 28                                   обл Тульская
# 29                              край Красноярский
# 30                               обл Владимирская
# 31                                  обл Псковская
# 32                              обл Волгоградская
# 33                                   обл Тверская
# 34                                 обл Московская
# 35                                обл Челябинская
# 36              обл Кемеровская область - Кузбасс
# 37                                  обл Самарская
# 38                                обл Челябинская
# 39                                  обл Иркутская
# 40                              обл Волгоградская
# 41                              г Санкт-Петербург
# 42                                край Камчатский
# 43                                 обл Московская
# 44                             край Краснодарский
# 45                              г Санкт-Петербург
# 46                               обл Владимирская
# 47                                 обл Ростовская
# 48                                 обл Московская
# 49                            край Ставропольский
# Name: region, dtype: category
# Categories (189, object): ['АО Ненецкий', 'АО Ханты-Мансийский', 'АО Ханты-Мансийский Автономный округ - Югра', 'АО Чукотский', ..., 'район Москва', 'респ Донецкая Народная', 'респ Луганская Народная', 'респ Хакасия']

# %%
train['settlement'].value_counts()
# Out:
# settlement
# г Москва                   247270
# г Санкт-Петербург          113231
# г Новосибирск               58199
# г Екатеринбург              53476
# г Казань                    43216
#                             ...
# деревня Нижние Адам-Учи         1
# деревня Нижние Бурнаши          1
# деревня Нижние Кропачи          1
# село Пахаревка                  1
# д Митяево                       1
# Name: count, Length: 47425, dtype: int64

# %%
class DataCleanerTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, region_column=None, region_reference=None):
        self.missing_cols = []
        self.region_column = region_column
        self.region_reference = region_reference
        self.reference_list = []
        self.label_encoders = {}

    def fit(self, X, y=None):
        # Сохраняем список колонок с пропущенными значениями для добавления индикаторов
        self.missing_cols = X.columns[X.isnull().any()].tolist()

        if self.region_column and self.region_reference:
            reference = pd.read_csv(self.region_reference)
            reference["region_name"] = reference["region_name"].str.lower().str.strip()
            self.reference_list = reference["region_name"].tolist()

        return self

    def transform(self, X):
        data = X.copy()
        
        # Добавляем индикаторы пропущенных значений перед заполнением пропусков
        data = self.add_missing_indicators(data)

        # Применяем функции для заполнения пропущенных значений
        data = self.fill_monthly_income(data)
        data = self.fill_work_experience(data)
        data = self.fill_requested_sum(data)
        data = self.fill_requested_amount_and_req_app_amount(data)
        data = self.fill_requested_period_days(data)
        data = self.fill_term_and_price(data)
        data = self.fill_elecs_sum_and_recurents_sum(data)
        data = self.fill_tamount(data)
        data = self.fill_nbki_score(data)
        data = self.fill_cnt_ext(data)
        data = self.fill_start_dt(data)
        data = self.fill_contact_cases(data)

        if self.region_column:
            data[self.region_column] = data[self.region_column].str.lower().str.strip()
            data[self.region_column] = data[self.region_column].apply(self.find_closest_match)

        data = self.process_settlement(data)

        # Генерация новых признаков
        data = self.generate_features(data)

        # Обработка дат
        data = self.process_dates(data)

        # Преобразование категориальных переменных
        data = self.encode_categorical_features(data)

        # Удаление ненужных признаков
        data = self.delete_bad_features(data)

        return data

    def fill_monthly_income(self, data):
        data['monthly_income'] = data.groupby('status')['monthly_income'].transform(
            lambda x: x.fillna(x.median()) if not np.isnan(x.median()) else x.fillna(data['monthly_income'].median())
        )
        return data

    def fill_work_experience(self, data):
        data['work_experience'] = data.groupby('status')['work_experience'].transform(
            lambda x: x.fillna(x.median()) if not np.isnan(x.median()) else x.fillna(data['work_experience'].median())
        )
        return data

    def fill_requested_sum(self, data):
        data['requested_sum'] = data['requested_sum'].fillna(
            data['approved_amount'] * (data['requested_sum'].median() / data['approved_amount'].median())
        )
        return data

    def fill_requested_amount_and_req_app_amount(self, data):
        data['requested_amount'] = data['requested_amount'].fillna(data['requested_sum'])
        data['req_app_amount'] = data['requested_amount'] - data['approved_amount']
        return data

    def fill_requested_period_days(self, data):
        data['requested_period_days'] = data.groupby('type')['requested_period_days'].transform(
            lambda x: x.fillna(x.median())
        )
        return data

    def fill_term_and_price(self, data):
        data['term'] = data['term'].fillna(0)
        data['price'] = data['price'].fillna(0)
        return data

    def fill_elecs_sum_and_recurents_sum(self, data):
        data['elecs_sum'] = data.groupby('repayment_type')['elecs_sum'].transform(
            lambda x: x.fillna(x.median())
        )
        data['recurents_sum'] = data.groupby('repayment_type')['recurents_sum'].transform(
            lambda x: x.fillna(x.median())
        )
        return data

    def fill_tamount(self, data):
        data['tamount'] = data['tamount'].fillna(data['principal'] + data['interest'] + data['issues'])
        return data

    def fill_nbki_score(self, data):
        data['nbki_score'] = data.groupby('status')['nbki_score'].transform(
            lambda x: x.fillna(x.median())
        )
        return data

    def fill_cnt_ext(self, data):
        data['cnt_ext'] = data['cnt_ext'].fillna(0)
        return data

    def add_missing_indicators(self, data):
        for col in self.missing_cols:
            data[f'{col}_missing'] = data[col].isnull().astype(int)
        return data

    def fill_contact_cases(self, data):
        data['contact_cases'] = data.groupby('repayment_type')['contact_cases'].transform(
            lambda x: x.fillna(x.median())
        )
        data['contact_cases'] = data['contact_cases'].fillna(data['contact_cases'].median())
        return data

    def fill_start_dt(self, data):
        data['start_dt'] = pd.to_datetime(data['start_dt'], errors='coerce')
        data['start_dt'] = data.groupby('client_id')['start_dt'].transform(
            lambda x: x.fillna(x.min())
        )
        data['start_dt'] = data['start_dt'].fillna(data['created_at'])
        return data

    def find_closest_match(self, region):
        match = process.extractOne(region, self.reference_list, scorer=fuzz.ratio)
        return match[0] if match and match[1] >= 60 else region  # Минимальный порог схожести - 60%

    def generate_features(self, data):
        # Платежное поведение
        data['payment_to_income_ratio'] = data['tamount'] / data['monthly_income']
        data['interest_to_principal_ratio'] = data['interest'] / data['principal']
        data['overdue_ratio'] = (data['overdue_interest'] + data['overdue_fee']) / data['principal']

        # Временные характеристики
        data['early_repayment'] = data['period_days'] - data['days_finish_loan']

        # Кредитное поведение
        data['approval_ratio'] = data['approved_amount'] / data['requested_amount']
        data['previous_extensions'] = data['cnt_ext'].fillna(0)
        data['had_extensions'] = data['cnt_ext'].notna().astype(int)

        # Признаки рискованности клиента
        data['risk_score'] = (
            (data['nbki_score'] * -1) +  # Инвертируем скор, чтобы высокие значения означали высокий риск
            (data['overdue_ratio'] * 2) +
            (data['had_extensions'] * 1.5)
        )

        # Поведенческие признаки
        data['digital_engagement'] = ((data['interface'] == 2) |
                                        (data['source'].isin([11, 12]))).astype(int)
        data['prefers_longer_terms'] = (data['requested_period_days'] > 
                                          data['requested_period_days'].mean()).astype(int)

        # Группируем по client_id и создаем новые признаки
        client_features = data.groupby('client_id').agg({
            'loan_id': 'count',  # Общее количество займов
            'days_finish_loan': 'mean',  # Средний срок закрытия займа
            'approved_amount': 'mean',  # Средняя сумма займа
            'cnt_ext': 'sum',  # Общее количество продлений
            'elecs_sum': 'sum',  # Сумма штрафов
            'created_at': 'max',  # Дата последнего займа
            'monthly_income': 'std',  # Вариация дохода
            'contact_cases': 'sum'  # Количество обращений в поддержку
        }).reset_index()

        client_features.rename(columns={
            'loan_id': 'total_loans',
            'days_finish_loan': 'avg_days_finish_loan',
            'approved_amount': 'avg_approved_amount',
            'cnt_ext': 'total_extensions',
            'elecs_sum': 'total_fees',
            'created_at': 'last_loan_date',
            'monthly_income': 'income_variation',
            'contact_cases': 'total_contacts'
        }, inplace=True)
        data = data.merge(client_features, on='client_id', how='left')
        
        # Финансовая нагрузка
        data['total_debt_burden'] = (data['elecs_sum'] + data['recurents_sum']) / data['monthly_income']
        data['disposable_income_ratio'] = 1 - data['total_debt_burden']

        return data

    def process_dates(self, data):
        date_columns = ['created_at', 'closed_at', 'start_dt']
        for col in date_columns:
            if col in data.columns:
                data[col] = pd.to_datetime(data[col], errors='coerce')  # Преобразуем в datetime
                data[col] = data[col].fillna(data['start_dt'])  # Заполняем отсутствующие значения датой из 'start_dt'
                # Преобразуем datetime в формат timestamp (количество секунд с начала эпохи)
                data[col] = data[col].astype('int64') // 10**9
        return data

    def encode_categorical_features(self, data):
        categorical_features = ['status', 'payment_frequency', 'source', 'first_source', 
                                'interface', 'type', 'repayment_type', 'settlement', 'client_type.1', 'region', 'gender']

        for feature in categorical_features:
            data[feature] = data[feature].astype(str).fillna("missing")  # Используем строку, чтобы избежать ошибки
            le = LabelEncoder()
            data[feature] = le.fit_transform(data[feature])
            self.label_encoders[feature] = le

        return data

    def clean_city_name(self, name):
        # Извлечение последнего слова
        name = name.split()[-1].lower().strip()
        # Удаление нежелательных символов (всего, что не буквы и не цифры)
        name = re.sub(r'[^а-яa-z0-9]', '', name)
        
        return name

    def process_settlement(self, data):
        data['settlement'] = data['settlement'].apply(self.clean_city_name)
        threshold = 400
        data_region_counts = data['settlement'].value_counts()
        data['settlement'] = data['settlement'].apply(lambda x: x if data_region_counts[x] > threshold else 'другие')

        return data

    def delete_bad_features(self, data):
        columns = ['loan_id', 'client_id']
        data.drop(columns=columns, inplace=True)
        
        return data

# %%
loan_id_test = test['loan_id']

# %%
# Пример использования
start_time = time.time()
transformer = DataCleanerTransformer(
    region_column="region", region_reference="region_reference.csv"
)
# Файл region_reference содержит правильно написанные названия регионов, исправление работает, так что, находятся 
# ближайше возможные записи из region_reference и по ним заменяются записи из train и test

train = transformer.fit_transform(train)
test = transformer.fit_transform(test)

end_time = time.time()
elapsed_time = round(end_time - start_time, 2)
print(f"\nElapsed Time: {elapsed_time} seconds")
# Out:
# Elapsed Time: 572.3 seconds

# %%
X = train.drop(['churn'], axis=1)
y = train['churn']

rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
# %%time
# Настройка модели
model = CatBoostClassifier(verbose=False, random_seed=42)

# Параметры для GridSearch
param_grid = {
    'iterations': [500],
    'depth': [6, 8],
}

# Инициализация GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='f1',  # Оптимизируем F1-метрику
    cv=3,          # Стратифицированная кросс-валидация
    verbose=2,
    n_jobs=-1      # Используем все доступные процессоры
)

# Обучение GridSearch
grid_search.fit(X_train, y_train)

# Вывод лучших параметров и метрик
print("\nЛучшие параметры: ", grid_search.best_params_)
print("Лучший F1-скор на кросс-валидации: ", grid_search.best_score_)

# Оценка на валидационных данных
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

print("\nОтчет о классификации на валидационных данных:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
#
# Лучшие параметры:  {'depth': 8, 'iterations': 500}
# Лучший F1-скор на кросс-валидации:  0.9358515554583898
#
# Отчет о классификации на валидационных данных:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94    236805
#            1       0.97      0.90      0.94    237647
#
#     accuracy                           0.94    474452
#    macro avg       0.94      0.94      0.94    474452
# weighted avg       0.94      0.94      0.94    474452
#
# CPU times: user 13min 7s, sys: 12.8 s, total: 13min 20s
# Wall time: 17min 12s

# %%
def submission(model, train_df, y_train, test_df, loan_id_submission, target_column='churn', output_prefix='submission_baseline'):
    
    X_train = train_df
    y_train = y_train
    X_test = test_df

    model.fit(X_train, y_train)

    y_pred_test = model.predict(X_test)

    # Подготовка DataFrame для сохранения
    submission = pd.DataFrame({
        'loan_id': loan_id_submission,
        'churn': y_pred_test
    })

    # Формирование имени файла
    model_name = type(model).__name__
    output_file = f"{output_prefix}_{model_name}.csv"

    # Сохранение файла
    submission.to_csv(output_file, index=False)
    print(f"Предсказания сохранены в файл: {output_file}")

# %%
model= CatBoostClassifier(depth=8, iterations=500)
submission(model, train.drop(columns=['churn', 'closed_at']), train['churn'], test, loan_id_test)
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.3868208	total: 991ms	remaining: 8m 14s
# 1:	learn: 0.2969361	total: 2.01s	remaining: 8m 21s
# 2:	learn: 0.2539313	total: 2.87s	remaining: 7m 55s
# 3:	learn: 0.2341843	total: 3.79s	remaining: 7m 49s
# 4:	learn: 0.2146058	total: 4.73s	remaining: 7m 48s
# 5:	learn: 0.2079574	total: 5.44s	remaining: 7m 27s
# 6:	learn: 0.2005728	total: 6.45s	remaining: 7m 34s
# 7:	learn: 0.1952080	total: 7.54s	remaining: 7m 43s
# 8:	learn: 0.1897037	total: 8.72s	remaining: 7m 55s
# 9:	learn: 0.1863603	total: 9.54s	remaining: 7m 47s
# 10:	learn: 0.1827046	total: 10.4s	remaining: 7m 40s
# 11:	learn: 0.1799363	total: 11.2s	remaining: 7m 34s
# 12:	learn: 0.1763581	total: 12s	remaining: 7m 30s
# 13:	learn: 0.1749933	total: 12.7s	remaining: 7m 20s
# 14:	learn: 0.1727718	total: 13.7s	remaining: 7m 21s
# 15:	learn: 0.1703832	total: 14.5s	remaining: 7m 20s
# 16:	learn: 0.1688658	total: 15.3s	remaining: 7m 14s
# 17:	learn: 0.1676968	total: 16.1s	remaining: 7m 12s
# 18:	learn: 0.1664476	total: 17.1s	remaining: 7m 13s
# 19:	learn: 0.1657938	total: 17.8s	remaining: 7m 6s
# 20:	learn: 0.1642664	total: 18.6s	remaining: 7m 4s
# 21:	learn: 0.1630276	total: 19.5s	remaining: 7m 3s
# 22:	learn: 0.1624345	total: 20.2s	remaining: 6m 59s
# 23:	learn: 0.1614202	total: 21.3s	remaining: 7m 2s
# 24:	learn: 0.1603226	total: 22s	remaining: 6m 58s
# 25:	learn: 0.1593379	total: 22.8s	remaining: 6m 55s
# 26:	learn: 0.1585362	total: 23.7s	remaining: 6m 54s
# 27:	learn: 0.1580120	total: 24.4s	remaining: 6m 51s
# 28:	learn: 0.1574674	total: 25.3s	remaining: 6m 51s
# 29:	learn: 0.1567358	total: 26.3s	remaining: 6m 52s
# 30:	learn: 0.1563182	total: 27s	remaining: 6m 48s
# 31:	learn: 0.1558572	total: 27.9s	remaining: 6m 47s
# 32:	learn: 0.1554682	total: 28.6s	remaining: 6m 44s
# 33:	learn: 0.1549224	total: 29.5s	remaining: 6m 44s
# 34:	learn: 0.1544766	total: 30.4s	remaining: 6m 43s
# 35:	learn: 0.1536236	total: 31.3s	remaining: 6m 43s
# 36:	learn: 0.1532374	total: 32s	remaining: 6m 40s
# 37:	learn: 0.1527864	total: 33s	remaining: 6m 41s
# 38:	learn: 0.1522381	total: 34s	remaining: 6m 42s
# 39:	learn: 0.1518954	total: 34.7s	remaining: 6m 39s
# 40:	learn: 0.1515698	total: 35.5s	remaining: 6m 36s
# 41:	learn: 0.1511772	total: 36.2s	remaining: 6m 35s
# 42:	learn: 0.1504367	total: 37.3s	remaining: 6m 36s
# 43:	learn: 0.1501752	total: 38.2s	remaining: 6m 36s
# 44:	learn: 0.1498224	total: 39.1s	remaining: 6m 35s
# 45:	learn: 0.1495771	total: 40.1s	remaining: 6m 35s
# 46:	learn: 0.1490853	total: 41.3s	remaining: 6m 37s
# 47:	learn: 0.1486972	total: 42.2s	remaining: 6m 37s
# 48:	learn: 0.1483315	total: 43s	remaining: 6m 35s
# 49:	learn: 0.1480665	total: 43.8s	remaining: 6m 34s
# 50:	learn: 0.1477269	total: 44.8s	remaining: 6m 34s
# 51:	learn: 0.1474470	total: 45.6s	remaining: 6m 32s
# 52:	learn: 0.1470930	total: 46.3s	remaining: 6m 30s
# 53:	learn: 0.1466865	total: 47.2s	remaining: 6m 30s
# 54:	learn: 0.1464661	total: 47.9s	remaining: 6m 27s
# 55:	learn: 0.1461925	total: 48.9s	remaining: 6m 27s
# 56:	learn: 0.1459880	total: 49.8s	remaining: 6m 26s
# 57:	learn: 0.1457318	total: 50.6s	remaining: 6m 25s
# 58:	learn: 0.1455849	total: 51.6s	remaining: 6m 25s
# 59:	learn: 0.1454649	total: 52.3s	remaining: 6m 23s
# 60:	learn: 0.1453504	total: 52.9s	remaining: 6m 20s
# 61:	learn: 0.1450324	total: 53.7s	remaining: 6m 19s
# 62:	learn: 0.1447519	total: 54.5s	remaining: 6m 18s
# 63:	learn: 0.1442894	total: 55.5s	remaining: 6m 18s
# 64:	learn: 0.1440067	total: 56.2s	remaining: 6m 16s
# 65:	learn: 0.1436721	total: 57.2s	remaining: 6m 16s
# 66:	learn: 0.1433559	total: 58.1s	remaining: 6m 15s
# 67:	learn: 0.1432357	total: 59s	remaining: 6m 15s
# 68:	learn: 0.1431361	total: 59.8s	remaining: 6m 13s
# 69:	learn: 0.1429460	total: 1m	remaining: 6m 11s
# 70:	learn: 0.1426364	total: 1m 1s	remaining: 6m 11s
# 71:	learn: 0.1424999	total: 1m 2s	remaining: 6m 10s
# 72:	learn: 0.1422917	total: 1m 3s	remaining: 6m 8s
# 73:	learn: 0.1421412	total: 1m 3s	remaining: 6m 7s
# 74:	learn: 0.1420276	total: 1m 4s	remaining: 6m 5s
# 75:	learn: 0.1418471	total: 1m 5s	remaining: 6m 3s
# 76:	learn: 0.1415814	total: 1m 6s	remaining: 6m 3s
# 77:	learn: 0.1413688	total: 1m 7s	remaining: 6m 3s
# 78:	learn: 0.1412127	total: 1m 7s	remaining: 6m 1s
# 79:	learn: 0.1409898	total: 1m 8s	remaining: 6m 1s
# 80:	learn: 0.1408346	total: 1m 9s	remaining: 6m 1s
# 81:	learn: 0.1406354	total: 1m 10s	remaining: 6m
# 82:	learn: 0.1405056	total: 1m 11s	remaining: 5m 59s
# 83:	learn: 0.1403579	total: 1m 12s	remaining: 5m 58s
# 84:	learn: 0.1402221	total: 1m 13s	remaining: 5m 59s
# 85:	learn: 0.1400304	total: 1m 14s	remaining: 5m 59s
# 86:	learn: 0.1399537	total: 1m 15s	remaining: 5m 57s
# 87:	learn: 0.1398110	total: 1m 16s	remaining: 5m 56s
# 88:	learn: 0.1395885	total: 1m 16s	remaining: 5m 54s
# 89:	learn: 0.1395389	total: 1m 17s	remaining: 5m 52s
# 90:	learn: 0.1395081	total: 1m 18s	remaining: 5m 51s
# 91:	learn: 0.1393051	total: 1m 18s	remaining: 5m 50s
# 92:	learn: 0.1391686	total: 1m 19s	remaining: 5m 48s
# 93:	learn: 0.1390868	total: 1m 20s	remaining: 5m 48s
# 94:	learn: 0.1389804	total: 1m 21s	remaining: 5m 48s
# 95:	learn: 0.1389068	total: 1m 22s	remaining: 5m 47s
# 96:	learn: 0.1388316	total: 1m 23s	remaining: 5m 46s
# 97:	learn: 0.1387357	total: 1m 24s	remaining: 5m 45s
# 98:	learn: 0.1386392	total: 1m 24s	remaining: 5m 43s
# 99:	learn: 0.1385891	total: 1m 25s	remaining: 5m 42s
# 100:	learn: 0.1384360	total: 1m 26s	remaining: 5m 42s
# 101:	learn: 0.1383574	total: 1m 27s	remaining: 5m 41s
# 102:	learn: 0.1383018	total: 1m 28s	remaining: 5m 40s
# 103:	learn: 0.1382580	total: 1m 28s	remaining: 5m 38s
# 104:	learn: 0.1380862	total: 1m 29s	remaining: 5m 37s
# 105:	learn: 0.1379942	total: 1m 30s	remaining: 5m 37s
# 106:	learn: 0.1379002	total: 1m 31s	remaining: 5m 36s
# 107:	learn: 0.1377973	total: 1m 32s	remaining: 5m 35s
# 108:	learn: 0.1377240	total: 1m 33s	remaining: 5m 33s
# 109:	learn: 0.1376897	total: 1m 33s	remaining: 5m 32s
# 110:	learn: 0.1374983	total: 1m 34s	remaining: 5m 31s
# 111:	learn: 0.1374325	total: 1m 35s	remaining: 5m 31s
# 112:	learn: 0.1373414	total: 1m 36s	remaining: 5m 29s
# 113:	learn: 0.1372626	total: 1m 37s	remaining: 5m 28s
# 114:	learn: 0.1371950	total: 1m 37s	remaining: 5m 27s
# 115:	learn: 0.1370566	total: 1m 38s	remaining: 5m 26s
# 116:	learn: 0.1370016	total: 1m 39s	remaining: 5m 26s
# 117:	learn: 0.1369156	total: 1m 40s	remaining: 5m 25s
# 118:	learn: 0.1368571	total: 1m 41s	remaining: 5m 24s
# 119:	learn: 0.1368045	total: 1m 42s	remaining: 5m 23s
# 120:	learn: 0.1366910	total: 1m 42s	remaining: 5m 22s
# 121:	learn: 0.1365702	total: 1m 43s	remaining: 5m 21s
# 122:	learn: 0.1364849	total: 1m 44s	remaining: 5m 20s
# 123:	learn: 0.1364454	total: 1m 45s	remaining: 5m 19s
# 124:	learn: 0.1364213	total: 1m 46s	remaining: 5m 19s
# 125:	learn: 0.1363641	total: 1m 47s	remaining: 5m 18s
# 126:	learn: 0.1362986	total: 1m 48s	remaining: 5m 18s
# 127:	learn: 0.1362313	total: 1m 49s	remaining: 5m 17s
# 128:	learn: 0.1361507	total: 1m 50s	remaining: 5m 16s
# 129:	learn: 0.1361055	total: 1m 50s	remaining: 5m 15s
# 130:	learn: 0.1360213	total: 1m 51s	remaining: 5m 15s
# 131:	learn: 0.1359486	total: 1m 52s	remaining: 5m 13s
# 132:	learn: 0.1358864	total: 1m 53s	remaining: 5m 12s
# 133:	learn: 0.1358007	total: 1m 54s	remaining: 5m 11s
# 134:	learn: 0.1357169	total: 1m 55s	remaining: 5m 11s
# 135:	learn: 0.1356727	total: 1m 55s	remaining: 5m 10s
# 136:	learn: 0.1356239	total: 1m 56s	remaining: 5m 8s
# 137:	learn: 0.1355833	total: 1m 57s	remaining: 5m 8s
# 138:	learn: 0.1355169	total: 1m 58s	remaining: 5m 7s
# 139:	learn: 0.1354949	total: 1m 59s	remaining: 5m 6s
# 140:	learn: 0.1354500	total: 2m	remaining: 5m 5s
# 141:	learn: 0.1353702	total: 2m	remaining: 5m 4s
# 142:	learn: 0.1353008	total: 2m 1s	remaining: 5m 3s
# 143:	learn: 0.1352756	total: 2m 2s	remaining: 5m 2s
# 144:	learn: 0.1351866	total: 2m 3s	remaining: 5m 1s
# 145:	learn: 0.1351359	total: 2m 4s	remaining: 5m
# 146:	learn: 0.1350138	total: 2m 5s	remaining: 5m
# 147:	learn: 0.1349869	total: 2m 5s	remaining: 4m 58s
# 148:	learn: 0.1349750	total: 2m 6s	remaining: 4m 57s
# 149:	learn: 0.1349526	total: 2m 7s	remaining: 4m 56s
# 150:	learn: 0.1349412	total: 2m 7s	remaining: 4m 55s
# 151:	learn: 0.1349245	total: 2m 8s	remaining: 4m 54s
# 152:	learn: 0.1349102	total: 2m 9s	remaining: 4m 53s
# 153:	learn: 0.1348902	total: 2m 9s	remaining: 4m 51s
# 154:	learn: 0.1348613	total: 2m 10s	remaining: 4m 50s
# 155:	learn: 0.1347961	total: 2m 11s	remaining: 4m 50s
# 156:	learn: 0.1347386	total: 2m 12s	remaining: 4m 49s
# 157:	learn: 0.1346925	total: 2m 13s	remaining: 4m 49s
# 158:	learn: 0.1345849	total: 2m 14s	remaining: 4m 48s
# 159:	learn: 0.1345219	total: 2m 15s	remaining: 4m 47s
# 160:	learn: 0.1344884	total: 2m 15s	remaining: 4m 46s
# 161:	learn: 0.1344736	total: 2m 16s	remaining: 4m 44s
# 162:	learn: 0.1344148	total: 2m 17s	remaining: 4m 44s
# 163:	learn: 0.1343424	total: 2m 18s	remaining: 4m 43s
# 164:	learn: 0.1342732	total: 2m 19s	remaining: 4m 42s
# 165:	learn: 0.1342272	total: 2m 20s	remaining: 4m 42s
# 166:	learn: 0.1341620	total: 2m 21s	remaining: 4m 41s
# 167:	learn: 0.1341324	total: 2m 21s	remaining: 4m 40s
# 168:	learn: 0.1340980	total: 2m 22s	remaining: 4m 39s
# 169:	learn: 0.1339931	total: 2m 23s	remaining: 4m 38s
# 170:	learn: 0.1338852	total: 2m 24s	remaining: 4m 38s
# 171:	learn: 0.1338395	total: 2m 25s	remaining: 4m 37s
# 172:	learn: 0.1337491	total: 2m 26s	remaining: 4m 36s
# 173:	learn: 0.1337048	total: 2m 27s	remaining: 4m 35s
# 174:	learn: 0.1336654	total: 2m 27s	remaining: 4m 34s
# 175:	learn: 0.1336343	total: 2m 28s	remaining: 4m 33s
# 176:	learn: 0.1336049	total: 2m 29s	remaining: 4m 32s
# 177:	learn: 0.1335677	total: 2m 29s	remaining: 4m 31s
# 178:	learn: 0.1335302	total: 2m 30s	remaining: 4m 30s
# 179:	learn: 0.1334802	total: 2m 31s	remaining: 4m 29s
# 180:	learn: 0.1334317	total: 2m 32s	remaining: 4m 28s
# 181:	learn: 0.1333747	total: 2m 33s	remaining: 4m 27s
# 182:	learn: 0.1333459	total: 2m 33s	remaining: 4m 26s
# 183:	learn: 0.1333045	total: 2m 34s	remaining: 4m 25s
# 184:	learn: 0.1332765	total: 2m 35s	remaining: 4m 24s
# 185:	learn: 0.1332219	total: 2m 36s	remaining: 4m 23s
# 186:	learn: 0.1331956	total: 2m 37s	remaining: 4m 22s
# 187:	learn: 0.1331727	total: 2m 37s	remaining: 4m 21s
# 188:	learn: 0.1331488	total: 2m 38s	remaining: 4m 21s
# 189:	learn: 0.1330852	total: 2m 39s	remaining: 4m 20s
# 190:	learn: 0.1330405	total: 2m 40s	remaining: 4m 19s
# 191:	learn: 0.1330159	total: 2m 40s	remaining: 4m 18s
# 192:	learn: 0.1329887	total: 2m 41s	remaining: 4m 17s
# 193:	learn: 0.1329669	total: 2m 42s	remaining: 4m 16s
# 194:	learn: 0.1329452	total: 2m 43s	remaining: 4m 15s
# 195:	learn: 0.1328956	total: 2m 44s	remaining: 4m 14s
# 196:	learn: 0.1328753	total: 2m 44s	remaining: 4m 13s
# 197:	learn: 0.1328559	total: 2m 45s	remaining: 4m 12s
# 198:	learn: 0.1328181	total: 2m 46s	remaining: 4m 11s
# 199:	learn: 0.1327787	total: 2m 47s	remaining: 4m 10s
# 200:	learn: 0.1327557	total: 2m 47s	remaining: 4m 9s
# 201:	learn: 0.1327350	total: 2m 48s	remaining: 4m 8s
# 202:	learn: 0.1326047	total: 2m 49s	remaining: 4m 7s
# 203:	learn: 0.1325262	total: 2m 50s	remaining: 4m 7s
# 204:	learn: 0.1325000	total: 2m 51s	remaining: 4m 6s
# 205:	learn: 0.1324564	total: 2m 52s	remaining: 4m 5s
# 206:	learn: 0.1324317	total: 2m 53s	remaining: 4m 5s
# 207:	learn: 0.1324072	total: 2m 53s	remaining: 4m 3s
# 208:	learn: 0.1323698	total: 2m 54s	remaining: 4m 3s
# 209:	learn: 0.1323408	total: 2m 55s	remaining: 4m 2s
# 210:	learn: 0.1323100	total: 2m 56s	remaining: 4m 1s
# 211:	learn: 0.1322690	total: 2m 57s	remaining: 4m
# 212:	learn: 0.1322549	total: 2m 58s	remaining: 3m 59s
# 213:	learn: 0.1322262	total: 2m 58s	remaining: 3m 58s
# 214:	learn: 0.1321909	total: 2m 59s	remaining: 3m 57s
# 215:	learn: 0.1321557	total: 3m	remaining: 3m 57s
# 216:	learn: 0.1321336	total: 3m 1s	remaining: 3m 56s
# 217:	learn: 0.1321083	total: 3m 1s	remaining: 3m 55s
# 218:	learn: 0.1320937	total: 3m 2s	remaining: 3m 54s
# 219:	learn: 0.1320807	total: 3m 3s	remaining: 3m 53s
# 220:	learn: 0.1320577	total: 3m 4s	remaining: 3m 52s
# 221:	learn: 0.1320333	total: 3m 4s	remaining: 3m 51s
# 222:	learn: 0.1320093	total: 3m 5s	remaining: 3m 50s
# 223:	learn: 0.1319858	total: 3m 6s	remaining: 3m 49s
# 224:	learn: 0.1319490	total: 3m 7s	remaining: 3m 49s
# 225:	learn: 0.1319280	total: 3m 8s	remaining: 3m 48s
# 226:	learn: 0.1319013	total: 3m 8s	remaining: 3m 47s
# 227:	learn: 0.1318824	total: 3m 9s	remaining: 3m 46s
# 228:	learn: 0.1318235	total: 3m 10s	remaining: 3m 45s
# 229:	learn: 0.1317968	total: 3m 11s	remaining: 3m 44s
# 230:	learn: 0.1317838	total: 3m 11s	remaining: 3m 43s
# 231:	learn: 0.1317414	total: 3m 12s	remaining: 3m 42s
# 232:	learn: 0.1317191	total: 3m 13s	remaining: 3m 41s
# 233:	learn: 0.1316901	total: 3m 14s	remaining: 3m 40s
# 234:	learn: 0.1316569	total: 3m 15s	remaining: 3m 39s
# 235:	learn: 0.1316347	total: 3m 15s	remaining: 3m 39s
# 236:	learn: 0.1316058	total: 3m 16s	remaining: 3m 38s
# 237:	learn: 0.1315360	total: 3m 17s	remaining: 3m 37s
# 238:	learn: 0.1315130	total: 3m 18s	remaining: 3m 36s
# 239:	learn: 0.1314921	total: 3m 19s	remaining: 3m 35s
# 240:	learn: 0.1314730	total: 3m 19s	remaining: 3m 34s
# 241:	learn: 0.1314658	total: 3m 20s	remaining: 3m 33s
# 242:	learn: 0.1314522	total: 3m 21s	remaining: 3m 32s
# 243:	learn: 0.1314413	total: 3m 21s	remaining: 3m 31s
# 244:	learn: 0.1314158	total: 3m 22s	remaining: 3m 30s
# 245:	learn: 0.1313854	total: 3m 23s	remaining: 3m 29s
# 246:	learn: 0.1313637	total: 3m 24s	remaining: 3m 29s
# 247:	learn: 0.1313425	total: 3m 25s	remaining: 3m 28s
# 248:	learn: 0.1313349	total: 3m 26s	remaining: 3m 27s
# 249:	learn: 0.1313164	total: 3m 26s	remaining: 3m 26s
# 250:	learn: 0.1313066	total: 3m 27s	remaining: 3m 25s
# 251:	learn: 0.1312861	total: 3m 28s	remaining: 3m 24s
# 252:	learn: 0.1312530	total: 3m 29s	remaining: 3m 24s
# 253:	learn: 0.1312277	total: 3m 29s	remaining: 3m 23s
# 254:	learn: 0.1312095	total: 3m 30s	remaining: 3m 22s
# 255:	learn: 0.1311838	total: 3m 31s	remaining: 3m 21s
# 256:	learn: 0.1311684	total: 3m 32s	remaining: 3m 20s
# 257:	learn: 0.1311467	total: 3m 32s	remaining: 3m 19s
# 258:	learn: 0.1311256	total: 3m 33s	remaining: 3m 18s
# 259:	learn: 0.1310946	total: 3m 34s	remaining: 3m 18s
# 260:	learn: 0.1310741	total: 3m 35s	remaining: 3m 17s
# 261:	learn: 0.1310385	total: 3m 36s	remaining: 3m 16s
# 262:	learn: 0.1310237	total: 3m 36s	remaining: 3m 15s
# 263:	learn: 0.1310004	total: 3m 37s	remaining: 3m 14s
# 264:	learn: 0.1309752	total: 3m 38s	remaining: 3m 13s
# 265:	learn: 0.1309546	total: 3m 39s	remaining: 3m 12s
# 266:	learn: 0.1309203	total: 3m 40s	remaining: 3m 12s
# 267:	learn: 0.1309077	total: 3m 40s	remaining: 3m 11s
# 268:	learn: 0.1308797	total: 3m 41s	remaining: 3m 10s
# 269:	learn: 0.1308340	total: 3m 42s	remaining: 3m 9s
# 270:	learn: 0.1308203	total: 3m 43s	remaining: 3m 8s
# 271:	learn: 0.1308027	total: 3m 44s	remaining: 3m 7s
# 272:	learn: 0.1307741	total: 3m 44s	remaining: 3m 6s
# 273:	learn: 0.1307504	total: 3m 45s	remaining: 3m 5s
# 274:	learn: 0.1307298	total: 3m 46s	remaining: 3m 5s
# 275:	learn: 0.1307152	total: 3m 46s	remaining: 3m 4s
# 276:	learn: 0.1306890	total: 3m 47s	remaining: 3m 3s
# 277:	learn: 0.1306641	total: 3m 48s	remaining: 3m 2s
# 278:	learn: 0.1306386	total: 3m 49s	remaining: 3m 1s
# 279:	learn: 0.1306032	total: 3m 50s	remaining: 3m
# 280:	learn: 0.1305842	total: 3m 50s	remaining: 2m 59s
# 281:	learn: 0.1305739	total: 3m 51s	remaining: 2m 59s
# 282:	learn: 0.1305520	total: 3m 52s	remaining: 2m 58s
# 283:	learn: 0.1304484	total: 3m 53s	remaining: 2m 57s
# 284:	learn: 0.1304233	total: 3m 54s	remaining: 2m 56s
# 285:	learn: 0.1303921	total: 3m 55s	remaining: 2m 55s
# 286:	learn: 0.1303311	total: 3m 56s	remaining: 2m 55s
# 287:	learn: 0.1303110	total: 3m 57s	remaining: 2m 54s
# 288:	learn: 0.1302635	total: 3m 58s	remaining: 2m 54s
# 289:	learn: 0.1302399	total: 3m 59s	remaining: 2m 53s
# 290:	learn: 0.1302188	total: 3m 59s	remaining: 2m 52s
# 291:	learn: 0.1301976	total: 4m	remaining: 2m 51s
# 292:	learn: 0.1301891	total: 4m 1s	remaining: 2m 50s
# 293:	learn: 0.1301296	total: 4m 2s	remaining: 2m 49s
# 294:	learn: 0.1300979	total: 4m 2s	remaining: 2m 48s
# 295:	learn: 0.1300692	total: 4m 3s	remaining: 2m 47s
# 296:	learn: 0.1300563	total: 4m 4s	remaining: 2m 47s
# 297:	learn: 0.1300297	total: 4m 5s	remaining: 2m 46s
# 298:	learn: 0.1300028	total: 4m 6s	remaining: 2m 45s
# 299:	learn: 0.1299503	total: 4m 6s	remaining: 2m 44s
# 300:	learn: 0.1299217	total: 4m 7s	remaining: 2m 43s
# 301:	learn: 0.1298916	total: 4m 8s	remaining: 2m 43s
# 302:	learn: 0.1298656	total: 4m 9s	remaining: 2m 42s
# 303:	learn: 0.1298531	total: 4m 10s	remaining: 2m 41s
# 304:	learn: 0.1298096	total: 4m 11s	remaining: 2m 40s
# 305:	learn: 0.1297854	total: 4m 11s	remaining: 2m 39s
# 306:	learn: 0.1297599	total: 4m 12s	remaining: 2m 38s
# 307:	learn: 0.1297113	total: 4m 13s	remaining: 2m 37s
# 308:	learn: 0.1296882	total: 4m 14s	remaining: 2m 37s
# 309:	learn: 0.1296713	total: 4m 15s	remaining: 2m 36s
# 310:	learn: 0.1296289	total: 4m 16s	remaining: 2m 35s
# 311:	learn: 0.1296018	total: 4m 16s	remaining: 2m 34s
# 312:	learn: 0.1295815	total: 4m 17s	remaining: 2m 33s
# 313:	learn: 0.1295656	total: 4m 18s	remaining: 2m 33s
# 314:	learn: 0.1295387	total: 4m 19s	remaining: 2m 32s
# 315:	learn: 0.1295221	total: 4m 19s	remaining: 2m 31s
# 316:	learn: 0.1295050	total: 4m 20s	remaining: 2m 30s
# 317:	learn: 0.1294775	total: 4m 21s	remaining: 2m 29s
# 318:	learn: 0.1294531	total: 4m 22s	remaining: 2m 28s
# 319:	learn: 0.1294350	total: 4m 23s	remaining: 2m 28s
# 320:	learn: 0.1293800	total: 4m 24s	remaining: 2m 27s
# 321:	learn: 0.1293598	total: 4m 24s	remaining: 2m 26s
# 322:	learn: 0.1293095	total: 4m 25s	remaining: 2m 25s
# 323:	learn: 0.1292739	total: 4m 26s	remaining: 2m 24s
# 324:	learn: 0.1292606	total: 4m 27s	remaining: 2m 24s
# 325:	learn: 0.1292333	total: 4m 28s	remaining: 2m 23s
# 326:	learn: 0.1292096	total: 4m 29s	remaining: 2m 22s
# 327:	learn: 0.1291864	total: 4m 30s	remaining: 2m 21s
# 328:	learn: 0.1291661	total: 4m 31s	remaining: 2m 21s
# 329:	learn: 0.1291516	total: 4m 32s	remaining: 2m 20s
# 330:	learn: 0.1291212	total: 4m 32s	remaining: 2m 19s
# 331:	learn: 0.1291031	total: 4m 33s	remaining: 2m 18s
# 332:	learn: 0.1290856	total: 4m 34s	remaining: 2m 17s
# 333:	learn: 0.1290667	total: 4m 35s	remaining: 2m 16s
# 334:	learn: 0.1290461	total: 4m 36s	remaining: 2m 15s
# 335:	learn: 0.1290251	total: 4m 36s	remaining: 2m 15s
# 336:	learn: 0.1289811	total: 4m 37s	remaining: 2m 14s
# 337:	learn: 0.1289608	total: 4m 38s	remaining: 2m 13s
# 338:	learn: 0.1289466	total: 4m 39s	remaining: 2m 12s
# 339:	learn: 0.1289266	total: 4m 39s	remaining: 2m 11s
# 340:	learn: 0.1289099	total: 4m 40s	remaining: 2m 10s
# 341:	learn: 0.1289028	total: 4m 41s	remaining: 2m 9s
# 342:	learn: 0.1288895	total: 4m 41s	remaining: 2m 9s
# 343:	learn: 0.1288678	total: 4m 42s	remaining: 2m 8s
# 344:	learn: 0.1288472	total: 4m 43s	remaining: 2m 7s
# 345:	learn: 0.1288328	total: 4m 44s	remaining: 2m 6s
# 346:	learn: 0.1288194	total: 4m 45s	remaining: 2m 5s
# 347:	learn: 0.1287958	total: 4m 45s	remaining: 2m 4s
# 348:	learn: 0.1287856	total: 4m 46s	remaining: 2m 3s
# 349:	learn: 0.1287572	total: 4m 47s	remaining: 2m 3s
# 350:	learn: 0.1287400	total: 4m 48s	remaining: 2m 2s
# 351:	learn: 0.1287192	total: 4m 48s	remaining: 2m 1s
# 352:	learn: 0.1287004	total: 4m 49s	remaining: 2m
# 353:	learn: 0.1286804	total: 4m 50s	remaining: 1m 59s
# 354:	learn: 0.1286733	total: 4m 51s	remaining: 1m 58s
# 355:	learn: 0.1286448	total: 4m 51s	remaining: 1m 58s
# 356:	learn: 0.1286254	total: 4m 52s	remaining: 1m 57s
# 357:	learn: 0.1286077	total: 4m 53s	remaining: 1m 56s
# 358:	learn: 0.1285829	total: 4m 54s	remaining: 1m 55s
# 359:	learn: 0.1285705	total: 4m 55s	remaining: 1m 54s
# 360:	learn: 0.1285557	total: 4m 55s	remaining: 1m 53s
# 361:	learn: 0.1285362	total: 4m 56s	remaining: 1m 53s
# 362:	learn: 0.1285041	total: 4m 57s	remaining: 1m 52s
# 363:	learn: 0.1284606	total: 4m 58s	remaining: 1m 51s
# 364:	learn: 0.1284312	total: 4m 59s	remaining: 1m 50s
# 365:	learn: 0.1284020	total: 5m	remaining: 1m 49s
# 366:	learn: 0.1283815	total: 5m 1s	remaining: 1m 49s
# 367:	learn: 0.1283579	total: 5m 2s	remaining: 1m 48s
# 368:	learn: 0.1283305	total: 5m 3s	remaining: 1m 47s
# 369:	learn: 0.1283079	total: 5m 4s	remaining: 1m 46s
# 370:	learn: 0.1282700	total: 5m 5s	remaining: 1m 46s
# 371:	learn: 0.1282454	total: 5m 5s	remaining: 1m 45s
# 372:	learn: 0.1282309	total: 5m 6s	remaining: 1m 44s
# 373:	learn: 0.1281985	total: 5m 7s	remaining: 1m 43s
# 374:	learn: 0.1281802	total: 5m 8s	remaining: 1m 42s
# 375:	learn: 0.1281479	total: 5m 8s	remaining: 1m 41s
# 376:	learn: 0.1281212	total: 5m 9s	remaining: 1m 41s
# 377:	learn: 0.1280946	total: 5m 10s	remaining: 1m 40s
# 378:	learn: 0.1280806	total: 5m 11s	remaining: 1m 39s
# 379:	learn: 0.1280589	total: 5m 12s	remaining: 1m 38s
# 380:	learn: 0.1280397	total: 5m 13s	remaining: 1m 37s
# 381:	learn: 0.1280124	total: 5m 13s	remaining: 1m 36s
# 382:	learn: 0.1279769	total: 5m 14s	remaining: 1m 36s
# 383:	learn: 0.1279535	total: 5m 15s	remaining: 1m 35s
# 384:	learn: 0.1279391	total: 5m 16s	remaining: 1m 34s
# 385:	learn: 0.1279022	total: 5m 16s	remaining: 1m 33s
# 386:	learn: 0.1278900	total: 5m 17s	remaining: 1m 32s
# 387:	learn: 0.1278730	total: 5m 18s	remaining: 1m 31s
# 388:	learn: 0.1278494	total: 5m 19s	remaining: 1m 31s
# 389:	learn: 0.1278328	total: 5m 19s	remaining: 1m 30s
# 390:	learn: 0.1278180	total: 5m 20s	remaining: 1m 29s
# 391:	learn: 0.1277978	total: 5m 21s	remaining: 1m 28s
# 392:	learn: 0.1277315	total: 5m 22s	remaining: 1m 27s
# 393:	learn: 0.1277170	total: 5m 23s	remaining: 1m 26s
# 394:	learn: 0.1276746	total: 5m 24s	remaining: 1m 26s
# 395:	learn: 0.1276508	total: 5m 24s	remaining: 1m 25s
# 396:	learn: 0.1276328	total: 5m 25s	remaining: 1m 24s
# 397:	learn: 0.1276112	total: 5m 26s	remaining: 1m 23s
# 398:	learn: 0.1275901	total: 5m 27s	remaining: 1m 22s
# 399:	learn: 0.1275488	total: 5m 28s	remaining: 1m 22s
# 400:	learn: 0.1274989	total: 5m 29s	remaining: 1m 21s
# 401:	learn: 0.1274647	total: 5m 29s	remaining: 1m 20s
# 402:	learn: 0.1274443	total: 5m 30s	remaining: 1m 19s
# 403:	learn: 0.1274218	total: 5m 31s	remaining: 1m 18s
# 404:	learn: 0.1274058	total: 5m 32s	remaining: 1m 17s
# 405:	learn: 0.1273925	total: 5m 33s	remaining: 1m 17s
# 406:	learn: 0.1273717	total: 5m 34s	remaining: 1m 16s
# 407:	learn: 0.1273533	total: 5m 34s	remaining: 1m 15s
# 408:	learn: 0.1273324	total: 5m 36s	remaining: 1m 14s
# 409:	learn: 0.1273214	total: 5m 37s	remaining: 1m 13s
# 410:	learn: 0.1273060	total: 5m 37s	remaining: 1m 13s
# 411:	learn: 0.1272841	total: 5m 38s	remaining: 1m 12s
# 412:	learn: 0.1272703	total: 5m 39s	remaining: 1m 11s
# 413:	learn: 0.1272555	total: 5m 39s	remaining: 1m 10s
# 414:	learn: 0.1272472	total: 5m 40s	remaining: 1m 9s
# 415:	learn: 0.1272245	total: 5m 41s	remaining: 1m 8s
# 416:	learn: 0.1272098	total: 5m 41s	remaining: 1m 8s
# 417:	learn: 0.1271963	total: 5m 42s	remaining: 1m 7s
# 418:	learn: 0.1271793	total: 5m 43s	remaining: 1m 6s
# 419:	learn: 0.1271530	total: 5m 44s	remaining: 1m 5s
# 420:	learn: 0.1271319	total: 5m 45s	remaining: 1m 4s
# 421:	learn: 0.1271060	total: 5m 45s	remaining: 1m 3s
# 422:	learn: 0.1270875	total: 5m 46s	remaining: 1m 3s
# 423:	learn: 0.1270595	total: 5m 47s	remaining: 1m 2s
# 424:	learn: 0.1270361	total: 5m 48s	remaining: 1m 1s
# 425:	learn: 0.1270165	total: 5m 49s	remaining: 1m
# 426:	learn: 0.1269915	total: 5m 49s	remaining: 59.8s
# 427:	learn: 0.1269740	total: 5m 50s	remaining: 59s
# 428:	learn: 0.1269600	total: 5m 51s	remaining: 58.2s
# 429:	learn: 0.1269418	total: 5m 52s	remaining: 57.3s
# 430:	learn: 0.1269233	total: 5m 52s	remaining: 56.5s
# 431:	learn: 0.1269036	total: 5m 53s	remaining: 55.7s
# 432:	learn: 0.1268956	total: 5m 54s	remaining: 54.9s
# 433:	learn: 0.1268259	total: 5m 55s	remaining: 54.1s
# 434:	learn: 0.1268113	total: 5m 56s	remaining: 53.2s
# 435:	learn: 0.1267915	total: 5m 57s	remaining: 52.4s
# 436:	learn: 0.1267760	total: 5m 57s	remaining: 51.6s
# 437:	learn: 0.1267384	total: 5m 58s	remaining: 50.7s
# 438:	learn: 0.1267115	total: 5m 59s	remaining: 49.9s
# 439:	learn: 0.1266942	total: 6m	remaining: 49.1s
# 440:	learn: 0.1266732	total: 6m	remaining: 48.3s
# 441:	learn: 0.1266528	total: 6m 1s	remaining: 47.5s
# 442:	learn: 0.1266309	total: 6m 2s	remaining: 46.7s
# 443:	learn: 0.1266134	total: 6m 3s	remaining: 45.8s
# 444:	learn: 0.1266009	total: 6m 4s	remaining: 45s
# 445:	learn: 0.1265734	total: 6m 5s	remaining: 44.2s
# 446:	learn: 0.1265615	total: 6m 5s	remaining: 43.4s
# 447:	learn: 0.1265465	total: 6m 6s	remaining: 42.5s
# 448:	learn: 0.1265151	total: 6m 7s	remaining: 41.7s
# 449:	learn: 0.1264799	total: 6m 8s	remaining: 41s
# 450:	learn: 0.1264601	total: 6m 9s	remaining: 40.2s
# 451:	learn: 0.1264430	total: 6m 10s	remaining: 39.4s
# 452:	learn: 0.1264296	total: 6m 11s	remaining: 38.5s
# 453:	learn: 0.1263963	total: 6m 12s	remaining: 37.7s
# 454:	learn: 0.1263765	total: 6m 13s	remaining: 36.9s
# 455:	learn: 0.1263656	total: 6m 14s	remaining: 36.1s
# 456:	learn: 0.1263516	total: 6m 14s	remaining: 35.3s
# 457:	learn: 0.1263410	total: 6m 15s	remaining: 34.4s
# 458:	learn: 0.1263156	total: 6m 16s	remaining: 33.6s
# 459:	learn: 0.1262937	total: 6m 17s	remaining: 32.8s
# 460:	learn: 0.1262742	total: 6m 18s	remaining: 32s
# 461:	learn: 0.1262585	total: 6m 18s	remaining: 31.2s
# 462:	learn: 0.1262478	total: 6m 19s	remaining: 30.3s
# 463:	learn: 0.1262295	total: 6m 20s	remaining: 29.5s
# 464:	learn: 0.1262078	total: 6m 21s	remaining: 28.7s
# 465:	learn: 0.1261876	total: 6m 22s	remaining: 27.9s
# 466:	learn: 0.1261631	total: 6m 22s	remaining: 27.1s
# 467:	learn: 0.1261525	total: 6m 23s	remaining: 26.2s
# 468:	learn: 0.1261376	total: 6m 24s	remaining: 25.4s
# 469:	learn: 0.1261179	total: 6m 25s	remaining: 24.6s
# 470:	learn: 0.1261032	total: 6m 25s	remaining: 23.8s
# 471:	learn: 0.1260875	total: 6m 26s	remaining: 22.9s
# 472:	learn: 0.1260658	total: 6m 27s	remaining: 22.1s
# 473:	learn: 0.1260439	total: 6m 28s	remaining: 21.3s
# 474:	learn: 0.1260312	total: 6m 29s	remaining: 20.5s
# 475:	learn: 0.1260206	total: 6m 29s	remaining: 19.6s
# 476:	learn: 0.1260059	total: 6m 30s	remaining: 18.8s
# 477:	learn: 0.1259837	total: 6m 31s	remaining: 18s
# 478:	learn: 0.1259624	total: 6m 31s	remaining: 17.2s
# 479:	learn: 0.1259404	total: 6m 32s	remaining: 16.4s
# 480:	learn: 0.1259274	total: 6m 33s	remaining: 15.5s
# 481:	learn: 0.1259127	total: 6m 34s	remaining: 14.7s
# 482:	learn: 0.1258946	total: 6m 35s	remaining: 13.9s
# 483:	learn: 0.1258699	total: 6m 35s	remaining: 13.1s
# 484:	learn: 0.1258447	total: 6m 36s	remaining: 12.3s
# 485:	learn: 0.1258261	total: 6m 37s	remaining: 11.4s
# 486:	learn: 0.1258142	total: 6m 38s	remaining: 10.6s
# 487:	learn: 0.1257824	total: 6m 38s	remaining: 9.81s
# 488:	learn: 0.1257561	total: 6m 39s	remaining: 8.99s
# 489:	learn: 0.1257346	total: 6m 40s	remaining: 8.18s
# 490:	learn: 0.1257275	total: 6m 41s	remaining: 7.36s
# 491:	learn: 0.1257062	total: 6m 42s	remaining: 6.55s
# 492:	learn: 0.1256757	total: 6m 43s	remaining: 5.73s
# 493:	learn: 0.1256554	total: 6m 44s	remaining: 4.91s
# 494:	learn: 0.1256401	total: 6m 45s	remaining: 4.09s
# 495:	learn: 0.1256146	total: 6m 46s	remaining: 3.27s
# 496:	learn: 0.1255898	total: 6m 47s	remaining: 2.46s
# 497:	learn: 0.1255725	total: 6m 47s	remaining: 1.64s
# 498:	learn: 0.1255553	total: 6m 48s	remaining: 819ms
# 499:	learn: 0.1255537	total: 6m 49s	remaining: 0us
# Предсказания сохранены в файл: submission_baseline_CatBoostClassifier.csv
